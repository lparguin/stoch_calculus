# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np

# %%
output_notebook() # this makes sure that the Bokeh plots render inside the notebook
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1bcb8591-48d3-4890-a5f3-06483d14e46b">Loading BokehJS ...</span>
#     </div>

# %%
# Suppose we want to generate 1000 paths with 100 points on each path

# Generate 1000 paths of IID standard normal random variables
standard_normal_rv = np.random.standard_normal((1000, 100))

# Find an upper triangular matrix 
A = np.triu(np.ones((100, 100)))

brownian_motion = np.dot(standard_normal_rv, A)

# %%
brownian_motion # Here we have the paths
# Out:
# array([[ -0.03114406,  -0.30129576,  -0.57317131, ..., -14.64840579,
#         -13.82903864, -14.39005668],
#        [ -0.22494994,  -1.18491871,  -0.39084153, ...,   9.08306953,
#           6.5041324 ,   6.94153861],
#        [  0.13686687,   0.14716344,  -0.7361439 , ...,  -3.98023219,
#          -3.76677326,  -4.56260304],
#        ...,
#        [  1.01985832,   0.61940877,   0.78062245, ...,   1.65231028,
#           1.30606406,   2.85998973],
#        [  0.34293216,   0.26478012,   0.7154774 , ...,  12.1172898 ,
#          12.55104425,  13.10926381],
#        [  0.24586955,   1.36919957,   2.83335139, ...,  -8.12606442,
#          -9.35868851,  -9.24620599]])

# %%
# Now we want to implement a general way to plot the graph
# so we create a function

def plot(brownian_motion, title=''):
    
    # Get the shape of the multidimensional array
    row, col = brownian_motion.shape
    
    # Generate random colors depending on how many vectors you have simulated
    
    r = lambda: np.random.randint(0, 255)
    color = ['#%02X%02X%02X' % (r(), r(), r()) for _ in range(row)]
    
    # Generate the x_values for the number of paths
    
    x_axis = [np.arange(0, 1, 1 / col) for _ in range(row)]
    
    # Plot the graph with Bokeh multi_line
    # Also note that the object passed has to be a list object
    # not a NumPy Array object
    
    fig = figure(plot_width=800, plot_height=400, title=title)
    fig.multi_line(x_axis, list(brownian_motion), color=color)
    
    show(fig) # this renders the plot within the notebook

# %%
plot(brownian_motion, 'Brownian Motion')
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f656765b-c76d-4d4d-ad55-f50ebede4123"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f656765b-c76d-4d4d-ad55-f50ebede4123");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f656765b-c76d-4d4d-ad55-f50ebede4123");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f656765b-c76d-4d4d-ad55-f50ebede4123' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a8425ad8-efb8-451d-9cc5-cd6ab73e4ff1":{"roots":{"references":[{"attributes":{"plot":{"id":"55d83575-5d20-4fdd-aaa9-ec9fe23a3c52","subtype":"Figure","type":"Plot"},"ticker":{"id":"aaad6833-bc7f-4125-b0b5-7ae9ab8945bd","type":"BasicTicker"}},"id":"93b23484-b39d-4fd6-b549-38d25736876e","type":"Grid"},{"attributes":{},"id":"aaad6833-bc7f-4125-b0b5-7ae9ab8945bd","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Brownian Motion"},"id":"43d30877-7f9d-48fc-8f78-6d594d5b3977","type":"Title"},{"attributes":{},"id":"23d301ff-77e8-447d-ab58-73d4c2b09e61","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"560ce4eb-6e99-4028-a842-03ca50d69682","type":"DataRange1d"},{"attributes":{"formatter":{"id":"0b9bf213-f3d7-4fb6-9e0e-a378f99153de","type":"BasicTickFormatter"},"plot":{"id":"55d83575-5d20-4fdd-aaa9-ec9fe23a3c52","subtype":"Figure","type":"Plot"},"ticker":{"id":"aaad6833-bc7f-4125-b0b5-7ae9ab8945bd","type":"BasicTicker"}},"id":"84b49694-625b-4199-944f-1145fc22fc16","type":"LinearAxis"},{"attributes":{"formatter":{"id":"23d301ff-77e8-447d-ab58-73d4c2b09e61","type":"BasicTickFormatter"},"plot":{"id":"55d83575-5d20-4fdd-aaa9-ec9fe23a3c52","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad411196-d9fd-4a78-a353-eb8947718955","type":"BasicTicker"}},"id":"913acdda-8487-474a-b3c4-dc405219e4e5","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9442d67c-4c6f-4974-b613-659182308818","type":"PanTool"},{"id":"e264852b-3fa8-4653-a74b-ea9cc147c624","type":"WheelZoomTool"},{"id":"18d53f45-fe86-4a05-97b0-a683656cac87","type":"BoxZoomTool"},{"id":"34db78ef-d202-486f-9f1d-36f938588413","type":"SaveTool"},{"id":"352d5c07-49b3-4117-a4d0-a690010ff52d","type":"ResetTool"},{"id":"4f8a0d8f-1550-47bc-8020-f52398b9d626","type":"HelpTool"}]},"id":"d3a797cd-4395-4ff9-9154-8694d09e045b","type":"Toolbar"},{"attributes":{"below":[{"id":"84b49694-625b-4199-944f-1145fc22fc16","type":"LinearAxis"}],"left":[{"id":"913acdda-8487-474a-b3c4-dc405219e4e5","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"84b49694-625b-4199-944f-1145fc22fc16","type":"LinearAxis"},{"id":"93b23484-b39d-4fd6-b549-38d25736876e","type":"Grid"},{"id":"913acdda-8487-474a-b3c4-dc405219e4e5","type":"LinearAxis"},{"id":"4fe66f57-c0d8-42f9-9a48-ee9bcd44210d","type":"Grid"},{"id":"1af774dd-14a0-43e5-ad86-bd9cfefef096","type":"BoxAnnotation"},{"id":"15f722e6-6b26-400b-9dda-3f230993b584","type":"GlyphRenderer"}],"title":{"id":"43d30877-7f9d-48fc-8f78-6d594d5b3977","type":"Title"},"tool_events":{"id":"cb67b650-9583-4ca3-b171-e8970bb06e5a","type":"ToolEvents"},"toolbar":{"id":"d3a797cd-4395-4ff9-9154-8694d09e045b","type":"Toolbar"},"x_range":{"id":"f2789616-5f10-42cd-84c3-75c90e3684d0","type":"DataRange1d"},"y_range":{"id":"560ce4eb-6e99-4028-a842-03ca50d69682","type":"DataRange1d"}},"id":"55d83575-5d20-4fdd-aaa9-ec9fe23a3c52","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"55d83575-5d20-4fdd-aaa9-ec9fe23a3c52","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad411196-d9fd-4a78-a353-eb8947718955","type":"BasicTicker"}},"id":"4fe66f57-c0d8-42f9-9a48-ee9bcd44210d","type":"Grid"},{"attributes":{},"id":"ad411196-d9fd-4a78-a353-eb8947718955","type":"BasicTicker"},{"attributes":{"callback":null},"id":"f2789616-5f10-42cd-84c3-75c90e3684d0","type":"DataRange1d"},{"attributes":{"plot":{"id":"55d83575-5d20-4fdd-aaa9-ec9fe23a3c52","subtype":"Figure","type":"Plot"}},"id":"9442d67c-4c6f-4974-b613-659182308818","type":"PanTool"},{"attributes":{"plot":{"id":"55d83575-5d20-4fdd-aaa9-ec9fe23a3c52","subtype":"Figure","type":"Plot"}},"id":"e264852b-3fa8-4653-a74b-ea9cc147c624","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"rend ...
